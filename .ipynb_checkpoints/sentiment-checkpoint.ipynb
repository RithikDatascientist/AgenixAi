# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf

# %%
df  = pd.read_csv("realistic_balanced_chat_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   conversation_id  500 non-null    int64
#  1   patient_message  500 non-null    object
#  2   doctor_response  500 non-null    object
#  3   intent           500 non-null    object
#  4   sentiment        500 non-null    object
#  5   summary          500 non-null    object
#  6   key_points       500 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 27.5+ KB

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\arfit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arfit/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\arfit/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re 
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

stop_words = set(stopwords.words("english"))
ps = PorterStemmer()

# %%
import string
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
req_df = df[["patient_message","sentiment"]]
req_df['label'] = le.fit_transform(req_df['sentiment'])
# Out:
# C:\Users\arfit\AppData\Local\Temp\ipykernel_25812\4089496017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req_df['label'] = le.fit_transform(req_df['sentiment'])

# %%
req_df
# Out:
#                                        patient_message   sentiment  label
# 0    I've been waiting 45 minutes past my scheduled...      formal      2
# 1    What COVID safety measures are you currently f...     neutral      5
# 2    The antidepressant dosage doesn't seem effecti...    friendly      3
# 3    Your online portal isn't working and I can't a...    negative      4
# 4    I'd like to make a same-day urgent appointment...     neutral      5
# ..                                                 ...         ...    ...
# 495  My child needs a sports physical - do you have...     neutral      5
# 496  The doctor didn't explain my diagnosis clearly...  apologetic      0
# 497  There's sharp pain in my lower right abdomen t...      urgent      7
# 498               Do you accept my new insurance plan?    friendly      3
# 499  My blood sugar levels have stabilized - do I s...     neutral      5
#
# [500 rows x 3 columns]

# %%
def tokeniser(obj):
    obj = obj.lower()
    obj = nltk.word_tokenize(obj)
    res = [ word for word in obj  if word.isalnum()]
    obj = res 
    res = [i  for i in obj  if i not in stopwords.words('english') and  i not in string.punctuation]
    obj = res
    res = [ ps.stem(i)  for i in obj ]
    return " ".join(res)

# %%
tokeniser(" This i will meet you in the luch break eactly in 12pm at the stree! like we all ways use to meets i hope you don't forget")
# Out:
# 'meet luch break eactli 12pm stree like way use meet hope forget'

# %%
req_df['preprocessed_PM'] = req_df['patient_message'].apply(tokeniser)
# Out:
# C:\Users\arfit\AppData\Local\Temp\ipykernel_25812\1132334796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   req_df['preprocessed_PM'] = req_df['patient_message'].apply(tokeniser)

# %%
req_df
# Out:
#                                        patient_message   sentiment  label  \
# 0    I've been waiting 45 minutes past my scheduled...      formal      2
# 1    What COVID safety measures are you currently f...     neutral      5
# 2    The antidepressant dosage doesn't seem effecti...    friendly      3
# 3    Your online portal isn't working and I can't a...    negative      4
# 4    I'd like to make a same-day urgent appointment...     neutral      5
# ..                                                 ...         ...    ...
# 495  My child needs a sports physical - do you have...     neutral      5
# 496  The doctor didn't explain my diagnosis clearly...  apologetic      0
# 497  There's sharp pain in my lower right abdomen t...      urgent      7
# 498               Do you accept my new insurance plan?    friendly      3
# 499  My blood sugar levels have stabilized - do I s...     neutral      5
#
#                                        preprocessed_PM
# 0              wait 45 minut past schedul appoint time
# 1                   covid safeti measur current follow
# 2          antidepress dosag seem effect anymor adjust
# 3             onlin portal work ca access medic record
# 4                     like make urgent appoint possibl
# ..                                                 ...
# 495   child need sport physic pediatr appoint tomorrow
# 496  doctor explain diagnosi clearli mani unansw qu...
# 497            sharp pain lower right abdomen come goe
# 498                              accept new insur plan
# 499          blood sugar level stabil still need dosag
#
# [500 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
x = tfidf.fit_transform(req_df['preprocessed_PM']).toarray()

# %%
x.shape
# Out:
# (500, 213)

# %%
y = req_df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state = 42)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB ()
mnb = MultinomialNB ()
bnb = BernoulliNB ()

# %%
gnb.fit(x_train,y_train)
y_pred = gnb.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(precision_score(y_test, y_pred))
# Out:
# 0.08
# [[ 5  0  0  1  1  0  0  0]
#  [ 8  0  0  1  1  0  0  0]
#  [ 8  1  2  0  3  0  0  0]
#  [ 2  0  5  0  0  0  0  0]
#  [ 5  4  4  1  1  0  0  0]
#  [11  3  6  1  3  0  0  0]
#  [ 7  1  3  0  2  0  0  0]
#  [ 6  3  0  1  0  0  0  0]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       3 print(accuracy_score(y_test, y_pred))
#       4 print(confusion_matrix(y_test, y_pred))
# ----> 5 print(precision_score(y_test, y_pred))
#
# File c:\works\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\works\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2182, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2015 @validate_params(
#    2016     {
#    2017         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2042     zero_division="warn",
#    2043 ):
#    2044     """Compute the precision.
#    2045
#    2046     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    2180     array([0.5, 1. , 1. ])
#    2181     """
# -> 2182     p, _, _, _ = precision_recall_fscore_support(
#    2183         y_true,
#    2184         y_pred,
#    2185         labels=labels,
#    2186         pos_label=pos_label,
#    2187         average=average,
#    2188         warn_for=("precision",),
#    2189         sample_weight=sample_weight,
#    2190         zero_division=zero_division,
#    2191     )
#    2192     return p
#
# File c:\works\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File c:\works\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1767, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1604 """Compute precision, recall, F-measure and support for each class.
#    1605
#    1606 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1764  array([2, 2, 2]))
#    1765 """
#    1766 _check_zero_division(zero_division)
# -> 1767 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1769 # Calculate tp_sum, pred_sum, true_sum ###
#    1770 samplewise = average == "samples"
#
# File c:\works\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1556, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1554         if y_type == "multiclass":
#    1555             average_options.remove("samples")
# -> 1556         raise ValueError(
#    1557             "Target is %s but average='binary'. Please "
#    1558             "choose another average setting, one of %r." % (y_type, average_options)
#    1559         )
#    1560 elif pos_label not in (None, 1):
#    1561     warnings.warn(
#    1562         "Note that pos_label (set to %r) is ignored when "
#    1563         "average != 'binary' (got %r). You may use "
#    (...)
#    1566         UserWarning,
#    1567     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
